# %% [markdown]
# <a href="https://colab.research.google.com/github/drsunithaev/cancer_detection/blob/main/ViT_CNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### https://www.kaggle.com/code/essammohamed4320/brain-tumor-detection-using-cnn-vit/notebook

# %% [markdown]
# ## Install dependencies

# %%
# !nvidia-smi
# Out:
# Sat Dec  9 09:22:37 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   42C    P8     9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# !pip install visualkeras
# Out:
# Collecting visualkeras
#   Downloading visualkeras-0.0.2-py3-none-any.whl (12 kB)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from visualkeras) (9.4.0)
# Requirement already satisfied: numpy>=1.18.1 in /usr/local/lib/python3.10/dist-packages (from visualkeras) (1.23.5)
# Collecting aggdraw>=1.3.11 (from visualkeras)
#   Downloading aggdraw-1.3.18-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (993 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 993.7/993.7 kB 18.2 MB/s eta 0:00:00
# Installing collected packages: aggdraw, visualkeras
# Successfully installed aggdraw-1.3.18 visualkeras-0.0.2

# %%
# !pip install tensorflow_addons
# Out:
# Collecting tensorflow_addons
#   Downloading tensorflow_addons-0.23.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (611 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 611.8/611.8 kB 9.8 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow_addons) (23.2)
# Collecting typeguard<3.0.0,>=2.7 (from tensorflow_addons)
#   Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Installing collected packages: typeguard, tensorflow_addons
# Successfully installed tensorflow_addons-0.23.0 typeguard-2.13.3

# %%
import os
import warnings
import itertools
import cv2
import seaborn as sns
import pandas as pd
import numpy  as np
from PIL import Image
from sklearn.utils import class_weight
from sklearn.metrics import confusion_matrix, classification_report
from collections import Counter

import tensorflow as tf
import tensorflow_addons as tfa
import visualkeras
import plotly.express as px
import matplotlib.pyplot as plt
from sklearn.metrics import multilabel_confusion_matrix

from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.utils import plot_model
from tensorflow.keras import layers
from tensorflow.keras import regularizers
from sklearn.model_selection   import train_test_split
from keras.preprocessing.image import ImageDataGenerator

warnings.filterwarnings('ignore')
# %matplotlib inline
# Out:
# /usr/local/lib/python3.10/dist-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(

# %% [markdown]
# ### Set parameters

# %%
# General parameters
epochs = 15
pic_size = 240
np.random.seed(42)
tf.random.set_seed(42)

# %%
folder_path = "/content/drive/MyDrive/Brain/_MODELLING/training"
no_images = os.listdir(folder_path + '/0/')
yes_images = os.listdir(folder_path + '/1/')
dataset=[]
lab=[]

for image_name in no_images:
    image=cv2.imread(folder_path + '/0/' + image_name)
    image=Image.fromarray(image)
    image=image.resize((240,240))
    dataset.append(np.array(image))
    lab.append(0)

for image_name in yes_images:
    image=cv2.imread(folder_path + '/1/' + image_name)
    image=Image.fromarray(image)
    image=image.resize((240,240))
    dataset.append(np.array(image))
    lab.append(1)

# %%
dataset = np.array(dataset)
lab = np.array(lab)
print(dataset.shape, lab.shape)
# Out:
# (3009, 240, 240, 3) (3009,)

# %%
x_train, x_test, y_train, y_test = train_test_split(dataset, lab, test_size=0.2, shuffle=True, random_state=42)

# %%
def plot_state(state):
    plt.figure(figsize= (12,12))
    for i in range(1, 10, 1):
        plt.subplot(3,3,i)
        img = load_img(folder_path + "/" + state + "/" + os.listdir(folder_path + "/" + state)[i], target_size=(pic_size, pic_size))
        plt.imshow(img)
    plt.show()

# %% [markdown]
# ### Modeling using CNN

# %%
model = tf.keras.Sequential([

    tf.keras.layers.Conv2D(filters=32,kernel_size=(3,3),strides=(2,2), activation="relu", padding="valid",input_shape=(pic_size,pic_size,3)),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Conv2D(filters=32,kernel_size=(3,3),strides=(2,2), activation="relu", padding="valid"),
    tf.keras.layers.MaxPooling2D((2, 2)),

    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(units=64, activation='relu',
                          kernel_regularizer=regularizers.L1L2(l1=1e-3, l2=1e-3),
                          bias_regularizer=regularizers.L2(1e-2),
                          activity_regularizer=regularizers.L2(1e-3)),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(units=1, activation='sigmoid'),
])

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 119, 119, 32)      896
#
#  max_pooling2d (MaxPooling2  (None, 59, 59, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 29, 29, 32)        9248
#
#  max_pooling2d_1 (MaxPoolin  (None, 14, 14, 32)        0
#  g2D)
#
#  flatten (Flatten)           (None, 6272)              0
#
#  dense (Dense)               (None, 64)                401472
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_1 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 411681 (1.57 MB)
# Trainable params: 411681 (1.57 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
plot_model(model, show_shapes=True, show_layer_names=False)

# %%
visualkeras.layered_view(model, legend=True)
# Out:
# <PIL.Image.Image image mode=RGBA size=713x671>

# %%
class_weights = class_weight.compute_class_weight(class_weight = "balanced", classes= np.unique(y_train), y= y_train)
class_weights = dict(zip(np.unique(y_train), class_weights))
class_weights
# Out:
# {0: 0.8265796703296703, 1: 1.2655099894847528}

# %%
history = model.fit(x_train,y_train,epochs = 100, class_weight=class_weights, validation_data=(x_test, y_test),verbose=1)

# %% [markdown]
# ## CNN model Evaluation

# %%
plt.figure(figsize=(20,10))
plt.subplot(1, 2, 1)
plt.suptitle('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend(loc='upper right')

plt.subplot(1, 2, 2)
plt.ylabel('Accuracy', fontsize=16)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.legend(loc='lower right')
plt.show()

# %%
results = model.evaluate(x_test, y_test)
print('The current model achieved an accuracy of {}%!'.format(round(results[1]*100,2)))
# Out:
# 19/19 [==============================] - 0s 6ms/step - loss: 1.0761 - accuracy: 0.8256
# The current model achieved an accuracy of 82.56%!

# %%
# compute predictions
predictions = model.predict(x_test)
y_pred = []
for i in predictions:
    if i >= 0.5:
        y_pred.append(1)
    else:
        y_pred.append(0)
# Out:
# 19/19 [==============================] - 0s 5ms/step

# %%
def plot_confusion_matrix(cm, classes, title='Confusion matrix', cmap=plt.cm.Blues):
    cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    plt.figure(figsize=(10,10))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

# %%
# compute confusion matrix
cnf_matrix = confusion_matrix(y_test, y_pred)
np.set_printoptions(precision=2)
# plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=["Yes", "No"], title='Normalized confusion matrix')
plt.show()

# %% [markdown]
# ## Modeling using Vision Transformers(ViT)

# %%
learning_rate = 0.001
weight_decay = 0.0001
batch_size = 256
num_epochs = 100
image_size = 240  # We'll resize input images to this size
patch_size = 20  # Size of the patches to be extract from the input images
num_patches = (image_size // patch_size) ** 2
projection_dim = 64
num_heads = 4
transformer_units = [
    projection_dim * 2,
    projection_dim,
]  # Size of the transformer layers
transformer_layers = 8
mlp_head_units = [2048, 1024]  # Size of the dense layers of the final classifier

# %%
data_augmentation = tf.keras.Sequential(
    [
        layers.Normalization(),
        layers.Resizing(image_size, image_size),
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(factor=0.02),
        layers.RandomZoom(
            height_factor=0.2, width_factor=0.2
        ),
    ],
    name="data_augmentation",
)
# Compute the mean and the variance of the training data for normalization.
data_augmentation.layers[0].adapt(x_train)

# %%
def mlp(x, hidden_units, dropout_rate):
    for units in hidden_units:
        x = layers.Dense(units, activation=tf.nn.gelu)(x)
        x = layers.Dropout(dropout_rate)(x)
    return x

# %% [markdown]
# ### Implement patch creation as a layer

# %%
class Patches(layers.Layer):
    def __init__(self, patch_size):
        super(Patches, self).__init__()
        self.patch_size = patch_size

    def call(self, images):
        batch_size = tf.shape(images)[0]
        patches = tf.image.extract_patches(
            images=images,
            sizes=[1, self.patch_size, self.patch_size, 1],
            strides=[1, self.patch_size, self.patch_size, 1],
            rates=[1, 1, 1, 1],
            padding="VALID",
        )
        patch_dims = patches.shape[-1]
        patches = tf.reshape(patches, [batch_size, -1, patch_dims])
        return patches

# %%
plt.figure(figsize=(8, 8))
image = x_train[np.random.choice(range(x_train.shape[0]))]
plt.imshow(image.astype("uint8"))

resized_image = tf.image.resize(
    tf.convert_to_tensor([image]), size=(image_size, image_size)
)
patches = Patches(patch_size)(resized_image)
print(f"Image size: {image_size} X {image_size}")
print(f"Patch size: {patch_size} X {patch_size}")
print(f"Patches per image: {patches.shape[1]}")
print(f"Elements per patch: {patches.shape[-1]}")

n = int(np.sqrt(patches.shape[1]))
plt.figure(figsize=(8, 8))
for i, patch in enumerate(patches[0]):
    ax = plt.subplot(n, n, i + 1)
    patch_img = tf.reshape(patch, (patch_size, patch_size, 3))
    plt.imshow(patch_img.numpy().astype("uint8"))
    plt.axis("off")
# Out:
# Image size: 240 X 240
# Patch size: 20 X 20
# Patches per image: 144
# Elements per patch: 1200

# %% [markdown]
# ### Creating the patch encoder

# %%
class PatchEncoder(tf.keras.layers.Layer):
    def __init__(self, num_patches, projection_dim):
        super(PatchEncoder, self).__init__()
        self.num_patches = num_patches
        self.projection = layers.Dense(units=projection_dim)
        self.position_embedding = layers.Embedding(
            input_dim=num_patches, output_dim=projection_dim
        )

    def call(self, patch):
        positions = tf.range(start=0, limit=self.num_patches, delta=1)
        encoded = self.projection(patch) + self.position_embedding(positions)
        return encoded

# %% [markdown]
# ### Building the ViT

# %%
def create_vit_classifier():
    inputs = layers.Input(shape=(240, 240, 3))
    # Augment data.
    augmented = data_augmentation(inputs)
    # Create patches.
    patches = Patches(patch_size)(augmented)
    # Encode patches.
    encoded_patches = PatchEncoder(num_patches, projection_dim)(patches)

    # Create multiple layers of the Transformer block.
    for _ in range(transformer_layers):
        # Layer normalization 1.
        x1 = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
        # Create a multi-head attention layer.
        attention_output = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=projection_dim, dropout=0.1
        )(x1, x1)
        # Skip connection 1.
        x2 = layers.Add()([attention_output, encoded_patches])
        # Layer normalization 2.
        x3 = layers.LayerNormalization(epsilon=1e-6)(x2)
        # MLP.
        x3 = mlp(x3, hidden_units=transformer_units, dropout_rate=0.1)
        # Skip connection 2.
        encoded_patches = layers.Add()([x3, x2])

    # Create a [batch_size, projection_dim] tensor.
    representation = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
    representation = layers.Flatten()(representation)
    representation = layers.Dropout(0.5)(representation)
    # Add MLP.
    features = mlp(representation, hidden_units=mlp_head_units, dropout_rate=0.5)
    # Classify outputs.
    logits = layers.Dense(2)(features)
    # Create the Keras model.
    model = tf.keras.Model(inputs=inputs, outputs=logits)
    return model

# %%
def run_experiment(model):
    optimizer = tfa.optimizers.AdamW(
        learning_rate=learning_rate, weight_decay=weight_decay
    )

    model.compile(
        optimizer=optimizer,
        loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
        metrics=[
            tf.keras.metrics.SparseCategoricalAccuracy(name="accuracy"),
            tf.keras.metrics.SparseTopKCategoricalAccuracy(5, name="top-5-accuracy"),
        ],
    )

    checkpoint_filepath = "/tmp/checkpoint"
    checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
        checkpoint_filepath,
        monitor="val_accuracy",
        save_best_only=True,
        save_weights_only=True,
    )

    history = model.fit(
        x=x_train,
        y=y_train,
        batch_size=batch_size,
        epochs=num_epochs,
        validation_data=(x_test, y_test),
        callbacks=[checkpoint_callback],
    )

    model.load_weights(checkpoint_filepath)
    _, accuracy, top_5_accuracy = model.evaluate(x_test, y_test)
    print(f"Test accuracy: {round(accuracy * 100, 2)}%")
    print(f"Test top 5 accuracy: {round(top_5_accuracy * 100, 2)}%")

    return history

# %%
vit_classifier = create_vit_classifier()
vit_history = run_experiment(vit_classifier)
# Out:
# Epoch 1/100
# 10/10 [==============================] - 20s 745ms/step - loss: 7.3087 - accuracy: 0.5517 - top-5-accuracy: 1.0000 - val_loss: 0.6985 - val_accuracy: 0.6611 - val_top-5-accuracy: 1.0000
# Epoch 2/100
# 10/10 [==============================] - 5s 534ms/step - loss: 1.0448 - accuracy: 0.6381 - top-5-accuracy: 1.0000 - val_loss: 0.5058 - val_accuracy: 0.7824 - val_top-5-accuracy: 1.0000
# Epoch 3/100
# 10/10 [==============================] - 4s 448ms/step - loss: 0.6461 - accuracy: 0.6967 - top-5-accuracy: 1.0000 - val_loss: 0.5224 - val_accuracy: 0.7508 - val_top-5-accuracy: 1.0000
# Epoch 4/100
# 10/10 [==============================] - 4s 415ms/step - loss: 0.5935 - accuracy: 0.7046 - top-5-accuracy: 1.0000 - val_loss: 0.5615 - val_accuracy: 0.7209 - val_top-5-accuracy: 1.0000
# Epoch 5/100
# 10/10 [==============================] - 4s 437ms/step - loss: 0.5664 - accuracy: 0.7158 - top-5-accuracy: 1.0000 - val_loss: 0.5260 - val_accuracy: 0.7342 - val_top-5-accuracy: 1.0000
# Epoch 6/100
# 10/10 [==============================] - 6s 601ms/step - loss: 0.5316 - accuracy: 0.7358 - top-5-accuracy: 1.0000 - val_loss: 0.4850 - val_accuracy: 0.7907 - val_top-5-accuracy: 1.0000
# Epoch 7/100
# 10/10 [==============================] - 5s 456ms/step - loss: 0.5355 - accuracy: 0.7349 - top-5-accuracy: 1.0000 - val_loss: 0.4875 - val_accuracy: 0.7608 - val_top-5-accuracy: 1.0000
# Epoch 8/100
# 10/10 [==============================] - 4s 439ms/step - loss: 0.4930 - accuracy: 0.7549 - top-5-accuracy: 1.0000 - val_loss: 0.4788 - val_accuracy: 0.7791 - val_top-5-accuracy: 1.0000
# Epoch 9/100
# 10/10 [==============================] - 5s 537ms/step - loss: 0.4917 - accuracy: 0.7578 - top-5-accuracy: 1.0000 - val_loss: 0.4860 - val_accuracy: 0.8306 - val_top-5-accuracy: 1.0000
# Epoch 10/100
# 10/10 [==============================] - 6s 605ms/step - loss: 0.4689 - accuracy: 0.7690 - top-5-accuracy: 1.0000 - val_loss: 0.4280 - val_accuracy: 0.8422 - val_top-5-accuracy: 1.0000
# Epoch 11/100
# 10/10 [==============================] - 5s 539ms/step - loss: 0.4347 - accuracy: 0.7952 - top-5-accuracy: 1.0000 - val_loss: 0.3934 - val_accuracy: 0.8522 - val_top-5-accuracy: 1.0000
# Epoch 12/100
# 10/10 [==============================] - 4s 436ms/step - loss: 0.4377 - accuracy: 0.8110 - top-5-accuracy: 1.0000 - val_loss: 0.4012 - val_accuracy: 0.8389 - val_top-5-accuracy: 1.0000
# Epoch 13/100
# 10/10 [==============================] - 6s 608ms/step - loss: 0.3911 - accuracy: 0.8330 - top-5-accuracy: 1.0000 - val_loss: 0.3744 - val_accuracy: 0.8688 - val_top-5-accuracy: 1.0000
# Epoch 14/100
# 10/10 [==============================] - 4s 436ms/step - loss: 0.4023 - accuracy: 0.8284 - top-5-accuracy: 1.0000 - val_loss: 0.3519 - val_accuracy: 0.8671 - val_top-5-accuracy: 1.0000
# Epoch 15/100
# 10/10 [==============================] - 4s 409ms/step - loss: 0.3893 - accuracy: 0.8276 - top-5-accuracy: 1.0000 - val_loss: 0.3429 - val_accuracy: 0.8621 - val_top-5-accuracy: 1.0000
# Epoch 16/100
# 10/10 [==============================] - 4s 440ms/step - loss: 0.4108 - accuracy: 0.8226 - top-5-accuracy: 1.0000 - val_loss: 0.3724 - val_accuracy: 0.8439 - val_top-5-accuracy: 1.0000
# Epoch 17/100
# 10/10 [==============================] - 4s 418ms/step - loss: 0.3845 - accuracy: 0.8288 - top-5-accuracy: 1.0000 - val_loss: 0.3450 - val_accuracy: 0.8439 - val_top-5-accuracy: 1.0000
# Epoch 18/100
# 10/10 [==============================] - 4s 407ms/step - loss: 0.3781 - accuracy: 0.8421 - top-5-accuracy: 1.0000 - val_loss: 0.3853 - val_accuracy: 0.8522 - val_top-5-accuracy: 1.0000
# Epoch 19/100
# 10/10 [==============================] - 4s 408ms/step - loss: 0.3734 - accuracy: 0.8479 - top-5-accuracy: 1.0000 - val_loss: 0.3461 - val_accuracy: 0.8588 - val_top-5-accuracy: 1.0000
# Epoch 20/100
# 10/10 [==============================] - 4s 446ms/step - loss: 0.3514 - accuracy: 0.8475 - top-5-accuracy: 1.0000 - val_loss: 0.3402 - val_accuracy: 0.8688 - val_top-5-accuracy: 1.0000
# Epoch 21/100
# 10/10 [==============================] - 4s 446ms/step - loss: 0.3502 - accuracy: 0.8438 - top-5-accuracy: 1.0000 - val_loss: 0.3341 - val_accuracy: 0.8688 - val_top-5-accuracy: 1.0000
# Epoch 22/100
# 10/10 [==============================] - 4s 439ms/step - loss: 0.3488 - accuracy: 0.8558 - top-5-accuracy: 1.0000 - val_loss: 0.3248 - val_accuracy: 0.8638 - val_top-5-accuracy: 1.0000
# Epoch 23/100
# 10/10 [==============================] - 6s 600ms/step - loss: 0.3629 - accuracy: 0.8500 - top-5-accuracy: 1.0000 - val_loss: 0.3095 - val_accuracy: 0.8754 - val_top-5-accuracy: 1.0000
# Epoch 24/100
# 10/10 [==============================] - 4s 449ms/step - loss: 0.3569 - accuracy: 0.8504 - top-5-accuracy: 1.0000 - val_loss: 0.3220 - val_accuracy: 0.8704 - val_top-5-accuracy: 1.0000
# Epoch 25/100
# 10/10 [==============================] - 6s 574ms/step - loss: 0.3605 - accuracy: 0.8417 - top-5-accuracy: 1.0000 - val_loss: 0.3209 - val_accuracy: 0.8821 - val_top-5-accuracy: 1.0000
# Epoch 26/100
# 10/10 [==============================] - 4s 409ms/step - loss: 0.3568 - accuracy: 0.8425 - top-5-accuracy: 1.0000 - val_loss: 0.3054 - val_accuracy: 0.8821 - val_top-5-accuracy: 1.0000
# Epoch 27/100
# 10/10 [==============================] - 4s 454ms/step - loss: 0.3629 - accuracy: 0.8517 - top-5-accuracy: 1.0000 - val_loss: 0.3418 - val_accuracy: 0.8455 - val_top-5-accuracy: 1.0000
# Epoch 28/100
# 10/10 [==============================] - 4s 441ms/step - loss: 0.3487 - accuracy: 0.8554 - top-5-accuracy: 1.0000 - val_loss: 0.3110 - val_accuracy: 0.8738 - val_top-5-accuracy: 1.0000
# Epoch 29/100
# 10/10 [==============================] - 4s 409ms/step - loss: 0.3514 - accuracy: 0.8517 - top-5-accuracy: 1.0000 - val_loss: 0.3328 - val_accuracy: 0.8671 - val_top-5-accuracy: 1.0000
# Epoch 30/100
# 10/10 [==============================] - 4s 441ms/step - loss: 0.3447 - accuracy: 0.8567 - top-5-accuracy: 1.0000 - val_loss: 0.3370 - val_accuracy: 0.8588 - val_top-5-accuracy: 1.0000
# Epoch 31/100
# 10/10 [==============================] - 4s 427ms/step - loss: 0.3467 - accuracy: 0.8558 - top-5-accuracy: 1.0000 - val_loss: 0.3245 - val_accuracy: 0.8821 - val_top-5-accuracy: 1.0000
# Epoch 32/100
# 10/10 [==============================] - 4s 408ms/step - loss: 0.3428 - accuracy: 0.8563 - top-5-accuracy: 1.0000 - val_loss: 0.3116 - val_accuracy: 0.8787 - val_top-5-accuracy: 1.0000
# Epoch 33/100
# 10/10 [==============================] - 4s 409ms/step - loss: 0.3328 - accuracy: 0.8612 - top-5-accuracy: 1.0000 - val_loss: 0.3129 - val_accuracy: 0.8738 - val_top-5-accuracy: 1.0000
# Epoch 34/100
# 10/10 [==============================] - 4s 444ms/step - loss: 0.3315 - accuracy: 0.8633 - top-5-accuracy: 1.0000 - val_loss: 0.3126 - val_accuracy: 0.8754 - val_top-5-accuracy: 1.0000
# Epoch 35/100
# 10/10 [==============================] - 6s 590ms/step - loss: 0.3310 - accuracy: 0.8575 - top-5-accuracy: 1.0000 - val_loss: 0.3100 - val_accuracy: 0.8837 - val_top-5-accuracy: 1.0000
# Epoch 36/100
# 10/10 [==============================] - 4s 407ms/step - loss: 0.3337 - accuracy: 0.8691 - top-5-accuracy: 1.0000 - val_loss: 0.3096 - val_accuracy: 0.8771 - val_top-5-accuracy: 1.0000
# Epoch 37/100
# 10/10 [==============================] - 4s 439ms/step - loss: 0.3319 - accuracy: 0.8641 - top-5-accuracy: 1.0000 - val_loss: 0.3489 - val_accuracy: 0.8787 - val_top-5-accuracy: 1.0000
# Epoch 38/100
# 10/10 [==============================] - 4s 428ms/step - loss: 0.3364 - accuracy: 0.8571 - top-5-accuracy: 1.0000 - val_loss: 0.3073 - val_accuracy: 0.8837 - val_top-5-accuracy: 1.0000
# Epoch 39/100
# 10/10 [==============================] - 4s 439ms/step - loss: 0.3470 - accuracy: 0.8583 - top-5-accuracy: 1.0000 - val_loss: 0.3411 - val_accuracy: 0.8771 - val_top-5-accuracy: 1.0000
# Epoch 40/100
# 10/10 [==============================] - 4s 409ms/step - loss: 0.3362 - accuracy: 0.8621 - top-5-accuracy: 1.0000 - val_loss: 0.3315 - val_accuracy: 0.8804 - val_top-5-accuracy: 1.0000
# Epoch 41/100
# 10/10 [==============================] - 4s 444ms/step - loss: 0.3412 - accuracy: 0.8538 - top-5-accuracy: 1.0000 - val_loss: 0.3304 - val_accuracy: 0.8738 - val_top-5-accuracy: 1.0000
# Epoch 42/100
# 10/10 [==============================] - 5s 458ms/step - loss: 0.3418 - accuracy: 0.8542 - top-5-accuracy: 1.0000 - val_loss: 0.3096 - val_accuracy: 0.8821 - val_top-5-accuracy: 1.0000
# Epoch 43/100
# 10/10 [==============================] - 5s 462ms/step - loss: 0.3277 - accuracy: 0.8716 - top-5-accuracy: 1.0000 - val_loss: 0.3050 - val_accuracy: 0.8804 - val_top-5-accuracy: 1.0000
# Epoch 44/100
# 10/10 [==============================] - 4s 441ms/step - loss: 0.3196 - accuracy: 0.8687 - top-5-accuracy: 1.0000 - val_loss: 0.3006 - val_accuracy: 0.8787 - val_top-5-accuracy: 1.0000
# Epoch 45/100
# 10/10 [==============================] - 6s 612ms/step - loss: 0.3184 - accuracy: 0.8700 - top-5-accuracy: 1.0000 - val_loss: 0.3135 - val_accuracy: 0.8904 - val_top-5-accuracy: 1.0000
# Epoch 46/100
# 10/10 [==============================] - 4s 437ms/step - loss: 0.3109 - accuracy: 0.8683 - top-5-accuracy: 1.0000 - val_loss: 0.3099 - val_accuracy: 0.8870 - val_top-5-accuracy: 1.0000
# Epoch 47/100
# 10/10 [==============================] - 4s 439ms/step - loss: 0.3177 - accuracy: 0.8666 - top-5-accuracy: 1.0000 - val_loss: 0.3082 - val_accuracy: 0.8854 - val_top-5-accuracy: 1.0000
# Epoch 48/100
# 10/10 [==============================] - 4s 443ms/step - loss: 0.3378 - accuracy: 0.8633 - top-5-accuracy: 1.0000 - val_loss: 0.2972 - val_accuracy: 0.8870 - val_top-5-accuracy: 1.0000
# Epoch 49/100
# 10/10 [==============================] - 4s 449ms/step - loss: 0.3034 - accuracy: 0.8737 - top-5-accuracy: 1.0000 - val_loss: 0.2927 - val_accuracy: 0.8887 - val_top-5-accuracy: 1.0000
# Epoch 50/100
# 10/10 [==============================] - 5s 568ms/step - loss: 0.2995 - accuracy: 0.8725 - top-5-accuracy: 1.0000 - val_loss: 0.2717 - val_accuracy: 0.8920 - val_top-5-accuracy: 1.0000
# Epoch 51/100
# 10/10 [==============================] - 4s 417ms/step - loss: 0.2745 - accuracy: 0.8849 - top-5-accuracy: 1.0000 - val_loss: 0.2430 - val_accuracy: 0.8920 - val_top-5-accuracy: 1.0000
# Epoch 52/100
# 10/10 [==============================] - 4s 451ms/step - loss: 0.3824 - accuracy: 0.8392 - top-5-accuracy: 1.0000 - val_loss: 0.4389 - val_accuracy: 0.7990 - val_top-5-accuracy: 1.0000
# Epoch 53/100
# 10/10 [==============================] - 4s 436ms/step - loss: 0.3788 - accuracy: 0.8425 - top-5-accuracy: 1.0000 - val_loss: 0.3380 - val_accuracy: 0.8837 - val_top-5-accuracy: 1.0000
# Epoch 54/100
# 10/10 [==============================] - 4s 408ms/step - loss: 0.3524 - accuracy: 0.8563 - top-5-accuracy: 1.0000 - val_loss: 0.3044 - val_accuracy: 0.8787 - val_top-5-accuracy: 1.0000
# Epoch 55/100
# 10/10 [==============================] - 4s 418ms/step - loss: 0.3324 - accuracy: 0.8625 - top-5-accuracy: 1.0000 - val_loss: 0.3206 - val_accuracy: 0.8904 - val_top-5-accuracy: 1.0000
# Epoch 56/100
# 10/10 [==============================] - 5s 509ms/step - loss: 0.3450 - accuracy: 0.8554 - top-5-accuracy: 1.0000 - val_loss: 0.3227 - val_accuracy: 0.8787 - val_top-5-accuracy: 1.0000
# Epoch 57/100
# 10/10 [==============================] - 4s 448ms/step - loss: 0.3431 - accuracy: 0.8571 - top-5-accuracy: 1.0000 - val_loss: 0.3723 - val_accuracy: 0.8488 - val_top-5-accuracy: 1.0000
# Epoch 58/100
# 10/10 [==============================] - 4s 409ms/step - loss: 0.3573 - accuracy: 0.8484 - top-5-accuracy: 1.0000 - val_loss: 0.3229 - val_accuracy: 0.8904 - val_top-5-accuracy: 1.0000
# Epoch 59/100
# 10/10 [==============================] - 4s 449ms/step - loss: 0.3230 - accuracy: 0.8666 - top-5-accuracy: 1.0000 - val_loss: 0.3038 - val_accuracy: 0.8704 - val_top-5-accuracy: 1.0000
# Epoch 60/100
# 10/10 [==============================] - 4s 414ms/step - loss: 0.3154 - accuracy: 0.8695 - top-5-accuracy: 1.0000 - val_loss: 0.3101 - val_accuracy: 0.8754 - val_top-5-accuracy: 1.0000
# Epoch 61/100
# 10/10 [==============================] - 4s 438ms/step - loss: 0.3239 - accuracy: 0.8579 - top-5-accuracy: 1.0000 - val_loss: 0.3098 - val_accuracy: 0.8837 - val_top-5-accuracy: 1.0000
# Epoch 62/100
# 10/10 [==============================] - 4s 438ms/step - loss: 0.3144 - accuracy: 0.8671 - top-5-accuracy: 1.0000 - val_loss: 0.2936 - val_accuracy: 0.8904 - val_top-5-accuracy: 1.0000
# Epoch 63/100
# 10/10 [==============================] - 4s 430ms/step - loss: 0.3122 - accuracy: 0.8741 - top-5-accuracy: 1.0000 - val_loss: 0.2993 - val_accuracy: 0.8887 - val_top-5-accuracy: 1.0000
# Epoch 64/100
# 10/10 [==============================] - 4s 411ms/step - loss: 0.3091 - accuracy: 0.8774 - top-5-accuracy: 1.0000 - val_loss: 0.2823 - val_accuracy: 0.8854 - val_top-5-accuracy: 1.0000
# Epoch 65/100
# 10/10 [==============================] - 5s 467ms/step - loss: 0.2971 - accuracy: 0.8799 - top-5-accuracy: 1.0000 - val_loss: 0.2807 - val_accuracy: 0.8887 - val_top-5-accuracy: 1.0000
# Epoch 66/100
# 10/10 [==============================] - 5s 485ms/step - loss: 0.2835 - accuracy: 0.8795 - top-5-accuracy: 1.0000 - val_loss: 0.2807 - val_accuracy: 0.8904 - val_top-5-accuracy: 1.0000
# Epoch 67/100
# 10/10 [==============================] - 5s 482ms/step - loss: 0.3089 - accuracy: 0.8691 - top-5-accuracy: 1.0000 - val_loss: 0.2982 - val_accuracy: 0.8870 - val_top-5-accuracy: 1.0000
# Epoch 68/100
# 10/10 [==============================] - 10s 1s/step - loss: 0.3020 - accuracy: 0.8737 - top-5-accuracy: 1.0000 - val_loss: 0.2879 - val_accuracy: 0.8970 - val_top-5-accuracy: 1.0000
# Epoch 69/100
# 10/10 [==============================] - 5s 485ms/step - loss: 0.2973 - accuracy: 0.8799 - top-5-accuracy: 1.0000 - val_loss: 0.2815 - val_accuracy: 0.8904 - val_top-5-accuracy: 1.0000
# Epoch 70/100
# 10/10 [==============================] - 4s 452ms/step - loss: 0.2940 - accuracy: 0.8803 - top-5-accuracy: 1.0000 - val_loss: 0.2828 - val_accuracy: 0.8904 - val_top-5-accuracy: 1.0000
# Epoch 71/100
# 10/10 [==============================] - 5s 467ms/step - loss: 0.2974 - accuracy: 0.8833 - top-5-accuracy: 1.0000 - val_loss: 0.2844 - val_accuracy: 0.8887 - val_top-5-accuracy: 1.0000
# Epoch 72/100
# 10/10 [==============================] - 7s 705ms/step - loss: 0.2875 - accuracy: 0.8791 - top-5-accuracy: 1.0000 - val_loss: 0.2721 - val_accuracy: 0.9020 - val_top-5-accuracy: 1.0000
# Epoch 73/100
# 10/10 [==============================] - 6s 583ms/step - loss: 0.2946 - accuracy: 0.8729 - top-5-accuracy: 1.0000 - val_loss: 0.2719 - val_accuracy: 0.9070 - val_top-5-accuracy: 1.0000
# Epoch 74/100
# 10/10 [==============================] - 4s 410ms/step - loss: 0.2727 - accuracy: 0.8833 - top-5-accuracy: 1.0000 - val_loss: 0.2498 - val_accuracy: 0.8953 - val_top-5-accuracy: 1.0000
# Epoch 75/100
# 10/10 [==============================] - 4s 446ms/step - loss: 0.2611 - accuracy: 0.8857 - top-5-accuracy: 1.0000 - val_loss: 0.2417 - val_accuracy: 0.9070 - val_top-5-accuracy: 1.0000
# Epoch 76/100
# 10/10 [==============================] - 6s 583ms/step - loss: 0.2414 - accuracy: 0.9015 - top-5-accuracy: 1.0000 - val_loss: 0.2146 - val_accuracy: 0.9086 - val_top-5-accuracy: 1.0000
# Epoch 77/100
# 10/10 [==============================] - 4s 408ms/step - loss: 0.2300 - accuracy: 0.9044 - top-5-accuracy: 1.0000 - val_loss: 0.2553 - val_accuracy: 0.9003 - val_top-5-accuracy: 1.0000
# Epoch 78/100
# 10/10 [==============================] - 5s 565ms/step - loss: 0.2327 - accuracy: 0.9086 - top-5-accuracy: 1.0000 - val_loss: 0.1826 - val_accuracy: 0.9286 - val_top-5-accuracy: 1.0000
# Epoch 79/100
# 10/10 [==============================] - 6s 581ms/step - loss: 0.2006 - accuracy: 0.9244 - top-5-accuracy: 1.0000 - val_loss: 0.1917 - val_accuracy: 0.9319 - val_top-5-accuracy: 1.0000
# Epoch 80/100
# 10/10 [==============================] - 6s 568ms/step - loss: 0.1875 - accuracy: 0.9244 - top-5-accuracy: 1.0000 - val_loss: 0.1694 - val_accuracy: 0.9402 - val_top-5-accuracy: 1.0000
# Epoch 81/100
# 10/10 [==============================] - 4s 441ms/step - loss: 0.1699 - accuracy: 0.9373 - top-5-accuracy: 1.0000 - val_loss: 0.1727 - val_accuracy: 0.9385 - val_top-5-accuracy: 1.0000
# Epoch 82/100
# 10/10 [==============================] - 4s 453ms/step - loss: 0.1657 - accuracy: 0.9385 - top-5-accuracy: 1.0000 - val_loss: 0.1629 - val_accuracy: 0.9302 - val_top-5-accuracy: 1.0000
# Epoch 83/100
# 10/10 [==============================] - 5s 568ms/step - loss: 0.1617 - accuracy: 0.9406 - top-5-accuracy: 1.0000 - val_loss: 0.1545 - val_accuracy: 0.9435 - val_top-5-accuracy: 1.0000
# Epoch 84/100
# 10/10 [==============================] - 4s 437ms/step - loss: 0.1894 - accuracy: 0.9335 - top-5-accuracy: 1.0000 - val_loss: 0.1769 - val_accuracy: 0.9302 - val_top-5-accuracy: 1.0000
# Epoch 85/100
# 10/10 [==============================] - 6s 609ms/step - loss: 0.1688 - accuracy: 0.9393 - top-5-accuracy: 1.0000 - val_loss: 0.1519 - val_accuracy: 0.9452 - val_top-5-accuracy: 1.0000
# Epoch 86/100
# 10/10 [==============================] - 4s 408ms/step - loss: 0.1706 - accuracy: 0.9364 - top-5-accuracy: 1.0000 - val_loss: 0.1754 - val_accuracy: 0.9402 - val_top-5-accuracy: 1.0000
# Epoch 87/100
# 10/10 [==============================] - 6s 587ms/step - loss: 0.1673 - accuracy: 0.9381 - top-5-accuracy: 1.0000 - val_loss: 0.1421 - val_accuracy: 0.9502 - val_top-5-accuracy: 1.0000
# Epoch 88/100
# 10/10 [==============================] - 6s 605ms/step - loss: 0.1648 - accuracy: 0.9356 - top-5-accuracy: 1.0000 - val_loss: 0.1399 - val_accuracy: 0.9535 - val_top-5-accuracy: 1.0000
# Epoch 89/100
# 10/10 [==============================] - 4s 405ms/step - loss: 0.1490 - accuracy: 0.9464 - top-5-accuracy: 1.0000 - val_loss: 0.1456 - val_accuracy: 0.9502 - val_top-5-accuracy: 1.0000
# Epoch 90/100
# 10/10 [==============================] - 4s 436ms/step - loss: 0.1647 - accuracy: 0.9427 - top-5-accuracy: 1.0000 - val_loss: 0.1774 - val_accuracy: 0.9203 - val_top-5-accuracy: 1.0000
# Epoch 91/100
# 10/10 [==============================] - 6s 608ms/step - loss: 0.1537 - accuracy: 0.9452 - top-5-accuracy: 1.0000 - val_loss: 0.1356 - val_accuracy: 0.9618 - val_top-5-accuracy: 1.0000
# Epoch 92/100
# 10/10 [==============================] - 4s 446ms/step - loss: 0.1466 - accuracy: 0.9493 - top-5-accuracy: 1.0000 - val_loss: 0.1310 - val_accuracy: 0.9468 - val_top-5-accuracy: 1.0000
# Epoch 93/100
# 10/10 [==============================] - 4s 437ms/step - loss: 0.1397 - accuracy: 0.9506 - top-5-accuracy: 1.0000 - val_loss: 0.1414 - val_accuracy: 0.9551 - val_top-5-accuracy: 1.0000
# Epoch 94/100
# 10/10 [==============================] - 4s 440ms/step - loss: 0.1272 - accuracy: 0.9526 - top-5-accuracy: 1.0000 - val_loss: 0.1353 - val_accuracy: 0.9568 - val_top-5-accuracy: 1.0000
# Epoch 95/100
# 10/10 [==============================] - 6s 589ms/step - loss: 0.1541 - accuracy: 0.9423 - top-5-accuracy: 1.0000 - val_loss: 0.1363 - val_accuracy: 0.9651 - val_top-5-accuracy: 1.0000
# Epoch 96/100
# 10/10 [==============================] - 4s 440ms/step - loss: 0.1343 - accuracy: 0.9526 - top-5-accuracy: 1.0000 - val_loss: 0.1626 - val_accuracy: 0.9502 - val_top-5-accuracy: 1.0000
# Epoch 97/100
# 10/10 [==============================] - 4s 439ms/step - loss: 0.1735 - accuracy: 0.9373 - top-5-accuracy: 1.0000 - val_loss: 0.1646 - val_accuracy: 0.9319 - val_top-5-accuracy: 1.0000
# Epoch 98/100
# 10/10 [==============================] - 4s 452ms/step - loss: 0.1750 - accuracy: 0.9402 - top-5-accuracy: 1.0000 - val_loss: 0.1502 - val_accuracy: 0.9452 - val_top-5-accuracy: 1.0000
# Epoch 99/100
# 10/10 [==============================] - 4s 440ms/step - loss: 0.1394 - accuracy: 0.9522 - top-5-accuracy: 1.0000 - val_loss: 0.1310 - val_accuracy: 0.9502 - val_top-5-accuracy: 1.0000
# Epoch 100/100
# 10/10 [==============================] - 4s 409ms/step - loss: 0.1285 - accuracy: 0.9560 - top-5-accuracy: 1.0000 - val_loss: 0.1243 - val_accuracy: 0.9568 - val_top-5-accuracy: 1.0000
# 19/19 [==============================] - 1s 33ms/step - loss: 0.1363 - accuracy: 0.9651 - top-5-accuracy: 1.0000
# Test accuracy: 96.51%
# Test top 5 accuracy: 100.0%

# %% [markdown]
# ### Notes about the ViT performance
# The state of the art results reported in the paper are achieved by pre-training the ViT model using the JFT-300M dataset, then fine-tuning it on the target dataset. To improve the model quality without pre-training, you can try to train the model for more epochs, use a larger number of Transformer layers, resize the input images, change the patch size, or increase the projection dimensions. Besides, as mentioned in the paper, the quality of the model is affected not only by architecture choices, but also by parameters such as the learning rate schedule, optimizer, weight decay, etc. In practice, it's recommended to fine-tune a ViT model that was pre-trained using a large, high-resolution dataset.

# %% [markdown]
# ## ViT model Evaluation

# %%
plt.figure(figsize=(20,10))
plt.subplot(1, 2, 1)
plt.suptitle('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(vit_history.history['loss'], label='Training Loss')
plt.plot(vit_history.history['val_loss'], label='Validation Loss')
plt.legend(loc='upper right')

plt.subplot(1, 2, 2)
plt.ylabel('Accuracy', fontsize=16)
plt.plot(vit_history.history['accuracy'], label='Training Accuracy')
plt.plot(vit_history.history['val_accuracy'], label='Validation Accuracy')
plt.legend(loc='lower right')
plt.show()

# %%
# compute predictions
vit_predictions = vit_classifier.predict(x_test)
vit_y_pred = [np.argmax(probas) for probas in vit_predictions]
# Out:
# 19/19 [==============================] - 2s 35ms/step

# %%
# compute confusion matrix
cnf_matrix = confusion_matrix(y_test, vit_y_pred)
np.set_printoptions(precision=2)
# plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=["Yes", "No"], title='Normalized confusion matrix')
plt.show()

# %%
vit_classifier.save('/content/drive/MyDrive/Brain/models/vit99.h')

# %%
model.save('/content/drive/MyDrive/Brain/models/cnn89.h')

# %%
vit_classifier.summary()

# %%
#visualkeras.layered_view(vit_classifier)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-52adf968e3d7> in <cell line: 1>()
# ----> 1 visualkeras.layered_view(vit_classifier)
#
# /usr/local/lib/python3.10/dist-packages/visualkeras/layered.py in layered_view(model, to_file, min_z, min_xy, max_z, max_xy, scale_z, scale_xy, type_ignore, index_ignore, color_map, one_dim_orientation, background_fill, draw_volume, padding, spacing, draw_funnel, shade_step, legend, font, font_color)
#      96             z = min(max(self_multiply(shape[3:]) * scale_z, z), max_z)
#      97         elif len(shape) == 3:
# ---> 98             x = min(max(shape[1] * scale_xy, x), max_xy)
#      99             y = min(max(shape[2] * scale_xy, y), max_xy)
#     100             z = min(max(z), max_z)
#
# TypeError: unsupported operand type(s) for *: 'NoneType' and 'int'
